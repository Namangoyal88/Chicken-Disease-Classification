# %%
1
# Out:
# 1

# %%
import time
from tqdm import tqdm

# Wrap your loop range
for i in tqdm(range(100)):
    time.sleep(0.1)  # Simulate work
# Out:
# 100%|██████████| 100/100 [00:10<00:00,  9.80it/s]
